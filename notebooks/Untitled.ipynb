# %%
import pandas as pd

# %%
pd.read_csv('../data/2016/masters10k.csv')
# Out:
#     Place        Fname           Lname  Age Sex                City State  \
# 0       1        James        O'Connor   42   M                Troy    NY
# 1       2          Tom         Kracker   51   M              Delmar    NY
# 2       3         John     Stadtlander   50   M        Clifton Park    NY
# 3       4          Jon           Rocco   49   M             Colonie    NY
# 4       5        Aaron        Knobloch   40   M         Guilderland    NY
# 5       6         John          Noonan   56   M        Ballston Spa    NY
# 6       7   Chong-Hwan             Son   50   M              Latham    NY
# 7       8         Mark      Stephenson   52   M           Esperance    NY
# 8       9      Russell           Lauer   53   M                Troy    NY
# 9      10         Todd           Smith   42   M       Voorheesville    NY
# 10     11        Brian         Northan   40   M         Guilderland    NY
# 11     12         Rick          Zachgo   45   M             Rexford    NY
# ...
