# %%
import pandas as pd

# %%
mine=pd.read_csv('../data/2019/3_ROTG/Res for GPv3.csv')
Renees=pd.read_csv('../data/2019/3_ROTG/Res for GPv2USATF.csv')

# %%
mine[20:23]
# Out:
#     Place  Bib First Name Last Name  Age Sex          City State GUN Time  \
# 20     21   74    Michael  Dinicola   44   M         Malta    NY    23:59
# 21     22  314    Matthew    Conant   43   M  Ballston Spa    NY    24:08
# 22     23  196  Christine     Myers   21   F      Altamont    NY    24:09
#
#     Pace  Usatf Number USATF
# 20  6:00  1.608890e+09     Y
# 21  6:02           NaN   NaN
# 22  6:03           NaN     N

# %%
Renees[20:23]
# Out:
#     Place  Bib First Name Last Name  Age Sex          City State  GUN Time  \
# 20     21   74    Michael  Dinicola   44   M         Malta    NY     23:59
# 21     22  314    Matthew    Conant   43   M  Ballston Spa    NY  24:08:00
# 22     23  196  Christine     Myers   21   F      Altamont    NY  24:09:00
#
#     Pace  Usatf Number USATF
# 20  6:00  1.608890e+09     Y
# 21  6:02           NaN   NaN
# 22  6:03           NaN     N

# %%
Renees.shape
# Out:
# (281, 12)

# %%
Renees['GUN Time']=mine['GUN Time']

# %%
Renees[20:23]
# Out:
#     Place  Bib First Name Last Name  Age Sex          City State GUN Time  \
# 20     21   74    Michael  Dinicola   44   M         Malta    NY    23:59
# 21     22  314    Matthew    Conant   43   M  Ballston Spa    NY    24:08
# 22     23  196  Christine     Myers   21   F      Altamont    NY    24:09
#
#     Pace  Usatf Number USATF
# 20  6:00  1.608890e+09     Y
# 21  6:02           NaN   NaN
# 22  6:03           NaN     N

# %%
Renees.to_csv('../data/2019/3_ROTG/Res for GPv4USATF.csv',index=False)

# %%
openbackup=pd.read_csv('../data/2019/3_ROTG/Res for GPv4USATF.csv')
openbackup[20:23]
# Out:
#     Place  Bib First Name Last Name  Age Sex          City State GUN Time  \
# 20     21   74    Michael  Dinicola   44   M         Malta    NY    23:59
# 21     22  314    Matthew    Conant   43   M  Ballston Spa    NY    24:08
# 22     23  196  Christine     Myers   21   F      Altamont    NY    24:09
#
#     Pace  Usatf Number USATF
# 20  6:00  1.608890e+09     Y
# 21  6:02           NaN   NaN
# 22  6:03           NaN     N
